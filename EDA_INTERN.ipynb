# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv("/content/SampleSuperstore.csv")
ds.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
ds.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
ds.shape
# Out:
# (9994, 13)

# %%
ds.loc[ds.duplicated()==True].shape
# Out:
# (17, 13)

# %%
ds.loc[ds.duplicated()==False].shape
# Out:
# (9977, 13)

# %%
ds = ds.drop_duplicates()
ds.shape
# Out:
# (9977, 13)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9977 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9977 non-null   object
#  1   Segment       9977 non-null   object
#  2   Country       9977 non-null   object
#  3   City          9977 non-null   object
#  4   State         9977 non-null   object
#  5   Postal Code   9977 non-null   int64
#  6   Region        9977 non-null   object
#  7   Category      9977 non-null   object
#  8   Sub-Category  9977 non-null   object
#  9   Sales         9977 non-null   float64
#  10  Quantity      9977 non-null   int64
#  11  Discount      9977 non-null   float64
#  12  Profit        9977 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
ds.head(50)
# Out:
#          Ship Mode      Segment        Country             City  \
# 0     Second Class     Consumer  United States        Henderson
# 1     Second Class     Consumer  United States        Henderson
# 2     Second Class    Corporate  United States      Los Angeles
# 3   Standard Class     Consumer  United States  Fort Lauderdale
# 4   Standard Class     Consumer  United States  Fort Lauderdale
# 5   Standard Class     Consumer  United States      Los Angeles
# 6   Standard Class     Consumer  United States      Los Angeles
# 7   Standard Class     Consumer  United States      Los Angeles
# 8   Standard Class     Consumer  United States      Los Angeles
# 9   Standard Class     Consumer  United States      Los Angeles
# 10  Standard Class     Consumer  United States      Los Angeles
# 11  Standard Class     Consumer  United States      Los Angeles
# 12  Standard Class     Consumer  United States          Concord
# 13  Standard Class     Consumer  United States          Seattle
# ...

# %%
ds['Profit'].describe()
# Out:
# count    9977.00000
# mean       28.69013
# std       234.45784
# min     -6599.97800
# 25%         1.72620
# 50%         8.67100
# 75%        29.37200
# max      8399.97600
# Name: Profit, dtype: float64

# %%
ds['Profit'].describe().plot()
# Out:
# <Axes: >

# %%
loss_ds = ds.loc[ds['Profit']<28]
loss_ds
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5     Standard Class   Consumer  United States      Los Angeles  California
# 6     Standard Class   Consumer  United States      Los Angeles  California
# ...              ...        ...            ...              ...         ...
# 9986  Standard Class   Consumer  United States      Los Angeles  California
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
#
# ...

# %%
loss_ds['Profit'].plot()
# Out:
# <Axes: >

# %%
ds.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
m_ds = ds[['Sales',"Discount","Profit","Quantity"]]
m_ds
# Out:
#          Sales  Discount    Profit  Quantity
# 0     261.9600      0.00   41.9136         2
# 1     731.9400      0.00  219.5820         3
# 2      14.6200      0.00    6.8714         2
# 3     957.5775      0.45 -383.0310         5
# 4      22.3680      0.20    2.5164         2
# ...        ...       ...       ...       ...
# 9989   25.2480      0.20    4.1028         3
# 9990   91.9600      0.00   15.6332         2
# 9991  258.5760      0.20   19.3932         2
# 9992   29.6000      0.00   13.3200         4
# 9993  243.1600      0.00   72.9480         2
#
# [9977 rows x 4 columns]

# %%
m_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9977 entries, 0 to 9993
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sales     9977 non-null   float64
#  1   Discount  9977 non-null   float64
#  2   Profit    9977 non-null   float64
#  3   Quantity  9977 non-null   int64
# dtypes: float64(3), int64(1)
# memory usage: 389.7 KB

# %%
m_ds.plot()
# Out:
# <Axes: >

# %%
plt.scatter(m_ds['Profit'],m_ds['Sales'],c =["red"],)

# %%
plt.scatter(m_ds['Profit'],m_ds['Sales'],c =["red"],)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_correlation(dataset):
    # Calculate correlation matrix
    corr_matrix = dataset.corr()

    # Plot correlation heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
    plt.title('Correlation Matrix of Variables')
    plt.show()
plot_correlation(ds)
# Out:
# <ipython-input-426-36f752176b5a>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = dataset.corr()

# %%
len(ds['Postal Code'].unique())
# Out:
# 631

# %%
ds['Postal Code'].value_counts().describe()
# Out:
# count    631.000000
# mean      15.811410
# std       30.836089
# min        1.000000
# 25%        3.000000
# 50%        6.000000
# 75%       14.000000
# max      263.000000
# Name: Postal Code, dtype: float64

# %%
plt.boxplot(ds['Postal Code'].value_counts())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e9123839c30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e912383a170>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e9123839990>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e912383a320>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e912383a560>],
#  'means': []}

# %%
plt.plot(ds['Postal Code'].value_counts())

# %%
import matplotlib.pyplot as plt

def plot_histogram(data, variable):
    # Plot histogram
    # plt.figure(figsize=(8, 6))
    plt.hist(data[variable], bins='auto', color='skyblue', alpha=0.7)
    plt.xlabel(variable)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {variable}')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()
plot_histogram(ds, 'Postal Code')

# %%
import matplotlib.pyplot as plt

def plot_histogram(data, variable):
    plt.hist(data[variable], bins='auto', color='skyblue', alpha=0.7)
    plt.xlabel(variable)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {variable}')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()
plot_histogram(ds, 'Postal Code')

# %%
plt.hist(ds["Postal Code"], bins=100, color='skyblue', alpha=0.7)
plt.show()

# %%
ds.head(50)
# Out:
#          Ship Mode      Segment        Country             City  \
# 0     Second Class     Consumer  United States        Henderson
# 1     Second Class     Consumer  United States        Henderson
# 2     Second Class    Corporate  United States      Los Angeles
# 3   Standard Class     Consumer  United States  Fort Lauderdale
# 4   Standard Class     Consumer  United States  Fort Lauderdale
# 5   Standard Class     Consumer  United States      Los Angeles
# 6   Standard Class     Consumer  United States      Los Angeles
# 7   Standard Class     Consumer  United States      Los Angeles
# 8   Standard Class     Consumer  United States      Los Angeles
# 9   Standard Class     Consumer  United States      Los Angeles
# 10  Standard Class     Consumer  United States      Los Angeles
# 11  Standard Class     Consumer  United States      Los Angeles
# 12  Standard Class     Consumer  United States          Concord
# 13  Standard Class     Consumer  United States          Seattle
# ...

# %%
ds.loc[ds['City']=='Henderson'].describe()
# Out:
#         Postal Code        Sales   Quantity   Discount      Profit
# count     51.000000    51.000000  51.000000  51.000000   51.000000
# mean   45160.882353   344.099373   3.882353   0.003922   96.310998
# std    11072.621944   576.636528   2.241848   0.028006  170.577109
# min    42420.000000     5.320000   1.000000   0.000000    0.000000
# 25%    42420.000000    21.305000   2.000000   0.000000    8.686800
# 50%    42420.000000    61.000000   3.000000   0.000000   24.228500
# 75%    42420.000000   378.390000   5.000000   0.000000   92.327100
# max    89015.000000  2573.820000  12.000000   0.200000  757.411200

# %%
ds['Postal Code'].unique()
ds['Postal Code'].value_counts(ascending=True)
# Out:
# 60067      1
# 38134      1
# 94061      1
# 93454      1
# 76248      1
#         ...
# 10011    192
# 94122    199
# 10009    229
# 10024    230
# 10035    263
# Name: Postal Code, Length: 631, dtype: int64

# %%
# Filtering Postal Codes that have less than 18 Orders

city_counts = ds['Postal Code'].value_counts()
ds
cities_to_keep = city_counts[city_counts >= 18].index.tolist()

filter_ds= ds[ds['Postal Code'].isin(cities_to_keep)]
filter_ds.head(50)
plt.scatter(filter_ds["Postal Code"],filter_ds["Profit"])
filter_ds["Postal Code"].describe()
# Out:
# count     7036.000000
# mean     55875.257959
# std      32841.402729
# min       1841.000000
# 25%      19805.000000
# 50%      60623.000000
# 75%      90036.000000
# max      98115.000000
# Name: Postal Code, dtype: float64

# %%
filter_ds.index = [i for i in range(filter_ds.shape[0])]

# %%
filter_ds['Postal Code'].value_counts()
# Out:
# 10035    263
# 10024    230
# 10009    229
# 94122    199
# 10011    192
#         ...
# 33178     18
# 38401     18
# 23320     18
# 33012     18
# 30076     18
# Name: Postal Code, Length: 121, dtype: int64

# %%
filter_ds['Profit'].describe()
# Out:
# count    7036.000000
# mean       27.685223
# std       238.161966
# min     -6599.978000
# 25%         1.512000
# 50%         8.332800
# 75%        28.765800
# max      6719.980800
# Name: Profit, dtype: float64

# %%
# Filtering aAreas Postal code that produce less than 5 profit or make loss

indexes = filter_ds.loc[filter_ds['Profit']<5]["Postal Code"].index
indexes
# Out:
# Int64Index([   4,   11,   12,   13,   16,   17,   19,   20,   22,   24,
#             ...
#             7001, 7005, 7006, 7014, 7018, 7019, 7021, 7028, 7029, 7035],
#            dtype='int64', length=2759)

# %%
filter_ds.shape
# Out:
# (7036, 13)

# %%
filter_ds['Country'].value_counts()
# Out:
# United States    7036
# Name: Country, dtype: int64

# %%
filter_ds["Improvement"] = pd.Series([])
# Out:
# <ipython-input-470-dd7c600e741e>:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   filter_ds["Improvement"] = pd.Series([])
# <ipython-input-470-dd7c600e741e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_ds["Improvement"] = pd.Series([])

# %%
filter_ds.loc[filter_ds["Improvement"]=="N"]["Profit"].plot()
# Out:
# <Axes: >

# %%
filter_ds.shape
# Out:
# (7036, 14)

# %%
for i in range(filter_ds.shape[0]):
 for j in indexes:
  if (i == j):
    filter_ds["Improvement"].iloc[j] = "Y"
filter_ds = filter_ds.fillna("N")
# Out:
# <ipython-input-473-d4ac812568c7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_ds["Improvement"].iloc[j] = "Y"

# %%
filter_ds.loc[filter_ds["Improvement"]=="N"]["Profit"].plot()
# Out:
# <Axes: >

# %%
filter_ds.head(50)
# Out:
#          Ship Mode      Segment        Country           City         State  \
# 0     Second Class     Consumer  United States      Henderson      Kentucky
# 1     Second Class     Consumer  United States      Henderson      Kentucky
# 2     Second Class    Corporate  United States    Los Angeles    California
# 3   Standard Class     Consumer  United States    Los Angeles    California
# 4   Standard Class     Consumer  United States    Los Angeles    California
# 5   Standard Class     Consumer  United States    Los Angeles    California
# 6   Standard Class     Consumer  United States    Los Angeles    California
# 7   Standard Class     Consumer  United States    Los Angeles    California
# 8   Standard Class     Consumer  United States    Los Angeles    California
# 9   Standard Class     Consumer  United States    Los Angeles    California
# 10  Standard Class     Consumer  United States        Seattle    Washington
# ...

# %%
weak_codes = filter_ds["Postal Code"].loc[filter_ds['Improvement']=="Y"]
weak_codes = weak_codes.values
weak_codes
# Out:
# array([90032, 76106, 76106, ..., 90032, 90032, 33180])

# %%
filter_ds.loc[filter_ds["Improvement"]=="Y"]["Profit"].plot()
# Out:
# <Axes: >

# %%
weak_codes = list(weak_codes)
filter_ds.loc[filter_ds['Postal Code'] == weak_codes[0]]
len(weak_codes)
# Out:
# 2759

# %%
data_l = []
for i in range(len(weak_codes)):
  e = list(filter_ds.loc[filter_ds['Postal Code'] == weak_codes[i]][["City","State"]].values[0])
  data_l.append((e,f" postal code is {weak_codes[i]}"))
data_l
# Out:
# [(['Los Angeles', 'California'], ' postal code is 90032'),
#  (['Fort Worth', 'Texas'], ' postal code is 76106'),
#  (['Fort Worth', 'Texas'], ' postal code is 76106'),
#  (['San Francisco', 'California'], ' postal code is 94109'),
#  (['Philadelphia', 'Pennsylvania'], ' postal code is 19140'),
#  (['Los Angeles', 'California'], ' postal code is 90049'),
#  (['Philadelphia', 'Pennsylvania'], ' postal code is 19140'),
#  (['Philadelphia', 'Pennsylvania'], ' postal code is 19140'),
#  (['Philadelphia', 'Pennsylvania'], ' postal code is 19140'),
#  (['Philadelphia', 'Pennsylvania'], ' postal code is 19140'),
#  (['Philadelphia', 'Pennsylvania'], ' postal code is 19140'),
#  (['Houston', 'Texas'], ' postal code is 77041'),
#  (['Houston', 'Texas'], ' postal code is 77041'),
#  (['Los Angeles', 'California'], ' postal code is 90049'),
#  (['Chicago', 'Illinois'], ' postal code is 60610'),
#  (['New York City', 'New York'], ' postal code is 10009'),
# ...

# %%
improvements_Var = pd.Series(data_l,name="PostalCode,City,State")
print(improvements_Var.shape)
print(len(improvements_Var.loc[improvements_Var.duplicated()]))
improvements_Var = improvements_Var.drop_duplicates()
improvements_Var.index = [i for i in range(improvements_Var.shape[0])]
print(f"These areas need work for more profit {improvements_Var.values}")
# Out:
# (2759,)
# 2639
# These areas need work for more profit [(['Los Angeles', 'California'], ' postal code is 90032')
#  (['Fort Worth', 'Texas'], ' postal code is 76106')
#  (['San Francisco', 'California'], ' postal code is 94109')
#  (['Philadelphia', 'Pennsylvania'], ' postal code is 19140')
#  (['Los Angeles', 'California'], ' postal code is 90049')
#  (['Houston', 'Texas'], ' postal code is 77041')
#  (['Chicago', 'Illinois'], ' postal code is 60610')
#  (['New York City', 'New York'], ' postal code is 10009')
#  (['Memphis', 'Tennessee'], ' postal code is 38109')
#  (['Houston', 'Texas'], ' postal code is 77070')
#  (['San Francisco', 'California'], ' postal code is 94122')
#  (['Chicago', 'Illinois'], ' postal code is 60623')
#  (['Los Angeles', 'California'], ' postal code is 90036')
#  (['Portland', 'Oregon'], ' postal code is 97206')
#  (['Aurora', 'Colorado'], ' postal code is 80013')
#  (['Charlotte', 'North Carolina'], ' postal code is 28205')
# ...

# %%
plt.scatter(ds["City"].loc[ds['City']=="New York City"],ds["Profit"].loc[ds['City']=="New York City"])

# %%
city_counts = ds['Postal Code'].value_counts()
ds
cities_to_keep = city_counts[city_counts >= 18].index.tolist()

filter_ds= ds[ds['Postal Code'].isin(cities_to_keep)]

# %%
filter_ds["City"].value_counts().describe()
# Out:
# count     79.000000
# mean      89.063291
# std      159.464998
# min        5.000000
# 25%       24.000000
# 50%       31.000000
# 75%       60.500000
# max      914.000000
# Name: City, dtype: float64

# %%
filter_ds["City"].value_counts()
# Out:
# New York City    914
# Los Angeles      746
# Philadelphia     536
# San Francisco    506
# Seattle          424
#                 ...
# Mcallen           19
# Chesapeake        18
# Roswell           18
# Hialeah           18
# Encinitas          5
# Name: City, Length: 79, dtype: int64

# %%
b_avg = filter_ds.loc[filter_ds["Profit"]<10]
b_avg["City"].unique()
# Out:
# array(['Los Angeles', 'Fort Worth', 'San Francisco', 'Philadelphia',
#        'Houston', 'New York City', 'Chicago', 'Jackson', 'Memphis',
#        'Minneapolis', 'Portland', 'Aurora', 'Charlotte', 'Columbus',
#        'Phoenix', 'Seattle', 'San Antonio', 'Newark', 'Decatur',
#        'Fairfield', 'Akron', 'Denver', 'Dallas', 'Detroit', 'Columbia',
#        'Tampa', 'San Diego', 'Colorado Springs', 'Arlington',
#        'Long Beach', 'Austin', 'Tucson', 'Miami', 'Richmond', 'Lawrence',
#        'Jacksonville', 'Huntsville', 'Rochester', 'Atlanta', 'Lakeland',
#        'Mesa', 'Springfield', 'Salem', 'Louisville', 'Cleveland',
#        'Hialeah', 'Oceanside', 'Toledo', 'San Jose', 'Henderson',
#        'Oakland', 'Encinitas', 'Roswell', 'Lakewood', 'Providence',
#        'Pasadena', 'Clinton', 'Glendale', 'Everett', 'El Paso',
#        'Indianapolis', 'Fayetteville', 'Baltimore', 'Milwaukee', 'Tulsa',
#        'Lafayette', 'Chesapeake', 'Wilmington', 'Knoxville',
# ...

# %%
plt.scatter(b_avg['City'],b_avg["Profit"])

# %%
plt.scatter(filter_ds['City'],filter_ds['Profit'])

# %%
filter_ds["Postal Code"].value_counts(ascending=True)
# Out:
# 30076     18
# 23320     18
# 33178     18
# 38401     18
# 33012     18
#         ...
# 10011    192
# 94122    199
# 10009    229
# 10024    230
# 10035    263
# Name: Postal Code, Length: 121, dtype: int64

# %%
filter_ds.loc[filter_ds["Postal Code"]==10035].plot()
# Out:
# <Axes: >
